# %% [markdown]
# <a href="https://colab.research.google.com/github/ArttuLe/Image_colorization_v1/blob/main/Image_colorization_v1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import os
import PIL
import PIL.Image
import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from skimage.color import rgb2lab

from keras.preprocessing.image import  img_to_array, load_img

# %%
# !unzip -uq "/content/drive/MyDrive/Train.zip" -d "/content/sample_data/Train_images/"

# %%
# !unzip -uq "/content/drive/MyDrive/Test.zip" -d "/content/sample_data/Test_images/"

# %% [markdown]
# Load images

# %%
size = (64,64)
folder="/content/sample_data/Train_images/Train/"
train_images = []

for filename in os.listdir(folder):
  train_images.append(load_img(os.path.join(folder,filename), target_size=size))
imshow(train_images[23])

# %% [markdown]
# Convert each image in the array into numpy arrays

# %%
train_data = []

for img in train_images:
  train_data.append(img_to_array(img))

train_data = np.array(train_data, dtype=float)
def MinMax(train_data,labels=["R","G","B"]):
    print("______________________________")
    for i, lab in enumerate(labels):
        mi = np.min(train_data[:,:,:,i])
        ma = np.max(train_data[:,:,:,i])
        print("{} : MIN={:8.4f}, MAX={:8.4f}".format(lab,mi,ma))
        
MinMax(train_data,labels=["R","G","B"])
# Out:
# ______________________________
# R : MIN=  0.0000, MAX=255.0000
# G : MIN=  0.0000, MAX=255.0000
# B : MIN=  0.0000, MAX=255.0000

# %% [markdown]
# Process to be done for the colorization of black and white images:
#
# 1.   Convert all training images from the RGB color space to the Lab color space.
# 2.   Use the Y channel as the input to the network and train the network to predict the correct ab channels
# 3.   Combine the input Y channel with the predicted a and b channels.
# 4.   Finally convert the Lab image back to RGB image.

# %%
train = train_data/255.0
MinMax(train,labels=["R","G","B"])
# Out:
# ______________________________
# R : MIN=  0.0000, MAX=  1.0000
# G : MIN=  0.0000, MAX=  1.0000
# B : MIN=  0.0000, MAX=  1.0000

# %% [markdown]
# *   Convert images into Lab colorspace and scale values to range -1,1
# *   Lab colorspace has value ranges 0,100 in L and -128,128 in ab
#
#
#
# ---

# %% [markdown]
# Split the channels so that the L channel is in X and ab in Y

# %%
from skimage.color import rgb2lab

train = rgb2lab(train)

# %%
MinMax(train, labels=["L","a","b"])
# Out:
# ______________________________
# L : MIN=  0.0000, MAX=100.0000
# a : MIN=-86.0584, MAX= 97.0538
# b : MIN=-106.9845, MAX= 93.9247

# %%
trainX = train[:,:,:,0]
trainY = train[:,:,:,1:]
trainY = trainY / 128.0
trainX = trainX / 100.0

# %%
trainY = trainY.reshape(9294,64,64,2)
trainX = trainX.reshape(9294,64,64,1)

# %%
MinMax(trainY, labels=["a","b"]),
MinMax(trainX, labels="L")
# Out:
# ______________________________
# a : MIN= -0.6723, MAX=  0.7582
# b : MIN= -0.8358, MAX=  0.7338
# ______________________________
# L : MIN=  0.0000, MAX=  1.0000

# %% [markdown]
# Simpler architecture?

# %%
model = tf.keras.Sequential([
      tf.keras.layers.InputLayer(input_shape=(None,None,1)),
      tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
      tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same', strides=(2,2)),
      tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
      tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same', strides=(2,2)),
      tf.keras.layers.Conv2D(256, (3,3), activation='relu', padding='same'),
      tf.keras.layers.Conv2D(256, (3,3), activation='relu', padding='same', strides=(2,2)),
      tf.keras.layers.Conv2D(512, (3,3), activation='relu', padding='same'),
      tf.keras.layers.Conv2D(256, (3,3), activation='relu', padding='same'),
      tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
      tf.keras.layers.UpSampling2D((2,2),),
      tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.UpSampling2D((2,2),),
      tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.UpSampling2D((2,2),),
      tf.keras.layers.Conv2D(2, (3,3), activation='tanh', padding='same'),
])

# %%
#saved_model = tf.keras.models.load_model('drive/MyDrive/Models/my_model_v1')

saved_model.summary()

# %%
model.summary()

# %%
model.compile(optimizer='adam',loss='mse',
             metrics='accuracy')
#saved_model.compile(optimizer='rmsprop',loss='mse',
#             metrics='accuracy')

# %%
model.fit(x=trainX, y=trainY, batch_size=12, epochs=100)


#saved_model.fit(x=trainX, y=trainY, batch_size=24, epochs=50, validation_split=0.15)
# Out:
# Epoch 1/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7504
# Epoch 2/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0029 - accuracy: 0.7491
# Epoch 3/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7525
# Epoch 4/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7553
# Epoch 5/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7532
# Epoch 6/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7531
# Epoch 7/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7544
# Epoch 8/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7544
# Epoch 9/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7538
# Epoch 10/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7555
# Epoch 11/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7551
# Epoch 12/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7560
# Epoch 13/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7533
# Epoch 14/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0028 - accuracy: 0.7546
# Epoch 15/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7554
# Epoch 16/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7570
# Epoch 17/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7554
# Epoch 18/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7576
# Epoch 19/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7579
# Epoch 20/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7597
# Epoch 21/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7559
# Epoch 22/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7561
# Epoch 23/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7561
# Epoch 24/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7591
# Epoch 25/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7584
# Epoch 26/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7571
# Epoch 27/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7609
# Epoch 28/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7585
# Epoch 29/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7578
# Epoch 30/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7587
# Epoch 31/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7601
# Epoch 32/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7598
# Epoch 33/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7605
# Epoch 34/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7610
# Epoch 35/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7592
# Epoch 36/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0027 - accuracy: 0.7570
# Epoch 37/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7625
# Epoch 38/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7616
# Epoch 39/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7577
# Epoch 40/100
# 775/775 [==============================] - 9s 11ms/step - loss: 0.0026 - accuracy: 0.7611
# Epoch 41/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7626
# Epoch 42/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7622
# Epoch 43/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7592
# Epoch 44/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7634
# Epoch 45/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7627
# Epoch 46/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7620
# Epoch 47/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7614
# Epoch 48/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7619
# Epoch 49/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7639
# Epoch 50/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7647
# Epoch 51/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0026 - accuracy: 0.7620
# Epoch 52/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7616
# Epoch 53/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7644
# Epoch 54/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7631
# Epoch 55/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7675
# Epoch 56/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7640
# Epoch 57/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7664
# Epoch 58/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7667
# Epoch 59/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7656
# Epoch 60/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7641
# Epoch 61/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7647
# Epoch 62/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7626
# Epoch 63/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7660
# Epoch 64/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7663
# Epoch 65/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7669
# Epoch 66/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7641
# Epoch 67/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7647
# Epoch 68/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7673
# Epoch 69/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7655
# Epoch 70/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7688
# Epoch 71/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7670
# Epoch 72/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7667
# Epoch 73/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7681
# Epoch 74/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7658
# Epoch 75/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7657
# Epoch 76/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7688
# Epoch 77/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7673
# Epoch 78/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7656
# Epoch 79/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7658
# Epoch 80/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7672
# Epoch 81/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7672
# Epoch 82/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7666
# Epoch 83/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0025 - accuracy: 0.7675
# Epoch 84/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7671
# Epoch 85/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7663
# Epoch 86/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7647
# Epoch 87/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7680
# Epoch 88/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7679
# Epoch 89/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7690
# Epoch 90/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7708
# Epoch 91/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7687
# Epoch 92/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7693
# Epoch 93/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7703
# Epoch 94/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7677
# Epoch 95/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7695
# Epoch 96/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7692
# Epoch 97/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7702
# Epoch 98/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7701
# Epoch 99/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7700
# Epoch 100/100
# 775/775 [==============================] - 9s 12ms/step - loss: 0.0024 - accuracy: 0.7677

# %%
#!pip install -q pyyaml h5py

# %%
#model.save('drive/MyDrive/Models/my_model_v1.2')
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/Models/my_model_v1.2/assets

# %%
loss, acc = model.evaluate(trainX,  trainY, verbose=2)

#loss, acc = saved_model.evaluate(trainX,  trainY, verbose=2)

print('\naccuracy:', acc)
print('\nloss:', loss)
# Out:
# 291/291 - 2s - loss: 0.0021 - accuracy: 0.8034
#
# accuracy: 0.8034254908561707
#
# loss: 0.0020635968539863825

# %% [markdown]
# Test the model by predicting on an image

# %%
from skimage.color import lab2rgb
from matplotlib.pyplot import imsave,imshow
from PIL import Image


img = load_img('/content/sample_data/Test_images/Test/lFvXyT.jpg', target_size=(256,256))
test_img = img_to_array(np.array(img, dtype=float))
test = test_img/255.0
test = rgb2lab(test)[:,:,0]
test = test / 100.0
test = test.reshape(1,256,256,1)

result = model.predict(test)
result *= 128 #rescale ab pixel-scale from -1,1 back to -128,128
test *= 100 # rescale L channel back to 0,100 range

pic = np.zeros((256,256,3)) # initialize an empty array for the result image
pic[:,:,0] = test[0][:,:,0] #take the L channel from the input
pic[:,:,1:] = result[0] # take the ab channels from the output
result_pic = lab2rgb(pic)



imshow(result_pic)
#imsave("drive/MyDrive/results/mountain.png", result_pic)

# %%
imshow(img)
